# %%
import os
import getpass

# %%
LANGFUSE_SECRET_KEY="YOUR_KEY"
LANGFUSE_PUBLIC_KEY="YOUR_KEY"
LANGFUSE_BASE_URL="https://cloud.langfuse.com"
MLFLOW_TRACKING_URI="YOUR_TRCAKING_URI"

# %%
# !python -m guardops_sdk.guardop.workers
