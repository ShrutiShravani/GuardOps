# %%
import os
import getpass

# %%
LANGFUSE_SECRET_KEY="sk-lf-36ec85e2-3ff4-40d9-bbd7-b4ffd9c3e3c1"
LANGFUSE_PUBLIC_KEY="pk-lf-98ebc3d3-984e-47f0-88f2-15ef66524a3f"
LANGFUSE_BASE_URL="https://cloud.langfuse.com"
MLFLOW_TRACKING_URI="http://127.0.0.1:5000"

# %%
# !python -m guardops_sdk.guardop.workers
# Out:
# Worker starting job for JOB-001-CLEAN
# Worker starting job for JOB-002-OVERRIDE-RUN
# Worker starting job for JOB-003-BUDGET-SHORT
# Worker starting job for INTERVIEW-SHRUTI-01
# [GUARD REGISTRY] Auto-detecting and compiling 'guard_manifest.json'...
# [REGISTRY] Voice_Generation_Node -> ['INTERVIEWER_PERSONA_BLEED_DETECTED']
# [REGISTRY] Voice_Generation_Node -> ['INTERVIEWER_PERSONA_BLEED_DETECTED', 'COMPETITOR_LEAK_SABOTAGE']
#
# ...
# [GUARD RUNTIME] Checking Node: 'CriticAgent'
# [DEBUG] Rule: <class 'str'>predicted_base_price | Extracted: 25.0 (Type: <class 'float'>) | Limit: <class 'float'> 5.0
# Target Rule Metric Key: 'predicted_base_price'
# Expected Condition: ConditionType.UNDER_FLOOR | Boundary: 5.0 (Type: <class 'float'>)
# [DEBUG] Rule: <class 'str'>operational_cost | Extracted: 120.0 (Type: <class 'float'>) | Limit: <class 'float'> 500.0
# Target Rule Metric Key: 'operational_cost'
# Expected Condition: ConditionType.OVER_CEILING | Boundary: 500.0 (Type: <class 'float'>)
# ...
